# %% [markdown]
# # Phase 2: Centroid Triangulation
# This notebook demonstrates how to calculate synthetic coordinates and find the 'thematic center' of multiple research papers.

# %%
import numpy as np
from xaptns.navigator import Navigator
from xaptns.search import VectorIndex

# Mock some vectors
v1 = np.random.rand(768)
v2 = np.random.rand(768)
v3 = np.random.rand(768)

nav = Navigator()
centroid = nav.calculate_centroid([v1, v2, v3])
print(f"Centroid shape: {centroid.shape}")
